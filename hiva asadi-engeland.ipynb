# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("EnglandWeather.csv")
data
# Out:
#              Date          Time        Summary Precip Type  Temperature (C)  \
# 0      2006-04-01  00:00:00.000  Partly Cloudy        rain         9.472222
# 1      2006-04-01  01:00:00.000  Partly Cloudy        rain         9.355556
# 2      2006-04-01  02:00:00.000  Mostly Cloudy        rain         9.377778
# 3      2006-04-01  03:00:00.000  Partly Cloudy        rain         8.288889
# 4      2006-04-01  04:00:00.000  Mostly Cloudy        rain         8.755556
# ...           ...           ...            ...         ...              ...
# 96448  2016-09-09  19:00:00.000  Partly Cloudy        rain        26.016667
# 96449  2016-09-09  20:00:00.000  Partly Cloudy        rain        24.583333
# 96450  2016-09-09  21:00:00.000  Partly Cloudy        rain        22.038889
# 96451  2016-09-09  22:00:00.000  Partly Cloudy        rain        21.522222
# 96452  2016-09-09  23:00:00.000  Partly Cloudy        rain        20.438889
#
#        Wind Speed (km/h)  Pressure (millibars)  Humidity
# ...

# %%
df=pd.DataFrame(data)
df
# Out:
#              Date          Time        Summary Precip Type  Temperature (C)  \
# 0      2006-04-01  00:00:00.000  Partly Cloudy        rain         9.472222
# 1      2006-04-01  01:00:00.000  Partly Cloudy        rain         9.355556
# 2      2006-04-01  02:00:00.000  Mostly Cloudy        rain         9.377778
# 3      2006-04-01  03:00:00.000  Partly Cloudy        rain         8.288889
# 4      2006-04-01  04:00:00.000  Mostly Cloudy        rain         8.755556
# ...           ...           ...            ...         ...              ...
# 96448  2016-09-09  19:00:00.000  Partly Cloudy        rain        26.016667
# 96449  2016-09-09  20:00:00.000  Partly Cloudy        rain        24.583333
# 96450  2016-09-09  21:00:00.000  Partly Cloudy        rain        22.038889
# 96451  2016-09-09  22:00:00.000  Partly Cloudy        rain        21.522222
# 96452  2016-09-09  23:00:00.000  Partly Cloudy        rain        20.438889
#
#        Wind Speed (km/h)  Pressure (millibars)  Humidity
# ...

# %%
df.describe()
# Out:
#        Temperature (C)  Wind Speed (km/h)  Pressure (millibars)      Humidity
# count     96453.000000       96453.000000          96453.000000  96453.000000
# mean         11.932678          10.810640           1003.235956      0.734899
# std           9.551546           6.913571            116.969906      0.195473
# min         -21.822222           0.000000              0.000000      0.000000
# 25%           4.688889           5.828200           1011.900000      0.600000
# 50%          12.000000           9.965900           1016.450000      0.780000
# 75%          18.838889          14.135800           1021.090000      0.890000
# max          39.905556          63.852600           1046.380000      1.000000

# %%
df2=pd.DataFrame(data, columns= ['Summary','Precip Type'])
df2
# Out:
#              Summary Precip Type
# 0      Partly Cloudy        rain
# 1      Partly Cloudy        rain
# 2      Mostly Cloudy        rain
# 3      Partly Cloudy        rain
# 4      Mostly Cloudy        rain
# ...              ...         ...
# 96448  Partly Cloudy        rain
# 96449  Partly Cloudy        rain
# 96450  Partly Cloudy        rain
# 96451  Partly Cloudy        rain
# 96452  Partly Cloudy        rain
#
# [96453 rows x 2 columns]

# %%
df2.describe()
# Out:
#               Summary Precip Type
# count           96453       95936
# unique             27           2
# top     Partly Cloudy        rain
# freq            31733       85224

# %%
df3=df.dropna(how='any')
df4=df2.dropna(how='any')
df3
# Out:
#              Date          Time        Summary Precip Type  Temperature (C)  \
# 0      2006-04-01  00:00:00.000  Partly Cloudy        rain         9.472222
# 1      2006-04-01  01:00:00.000  Partly Cloudy        rain         9.355556
# 2      2006-04-01  02:00:00.000  Mostly Cloudy        rain         9.377778
# 3      2006-04-01  03:00:00.000  Partly Cloudy        rain         8.288889
# 4      2006-04-01  04:00:00.000  Mostly Cloudy        rain         8.755556
# ...           ...           ...            ...         ...              ...
# 96448  2016-09-09  19:00:00.000  Partly Cloudy        rain        26.016667
# 96449  2016-09-09  20:00:00.000  Partly Cloudy        rain        24.583333
# 96450  2016-09-09  21:00:00.000  Partly Cloudy        rain        22.038889
# 96451  2016-09-09  22:00:00.000  Partly Cloudy        rain        21.522222
# 96452  2016-09-09  23:00:00.000  Partly Cloudy        rain        20.438889
#
#        Wind Speed (km/h)  Pressure (millibars)  Humidity
# ...

# %%
df4
# Out:
#              Summary Precip Type
# 0      Partly Cloudy        rain
# 1      Partly Cloudy        rain
# 2      Mostly Cloudy        rain
# 3      Partly Cloudy        rain
# 4      Mostly Cloudy        rain
# ...              ...         ...
# 96448  Partly Cloudy        rain
# 96449  Partly Cloudy        rain
# 96450  Partly Cloudy        rain
# 96451  Partly Cloudy        rain
# 96452  Partly Cloudy        rain
#
# [95936 rows x 2 columns]

# %%
plt.figure(figsize=(6,6), dpi=90)
plt.scatter(df3['Summary'],df3['Humidity'])
plt.xlabel("Summary")
plt.xticks(rotation=90)
plt.ylabel("Humidity")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(6,6), dpi=90)
plt.scatter(df3['Precip Type'],df3['Humidity'])
plt.xlabel("Precip Type")
plt.xticks(rotation=90)
plt.ylabel("Humidity")
plt.grid()
plt.show()

# %%
Year= pd.to_datetime(df3.Date).dt.year

# %%
import seaborn as sns

# %%
plt.figure(figsize=(10,8))
plt.title('Humidity of year')
sns.countplot(x=Year)
# Out:
# <AxesSubplot:title={'center':'Humidity of year'}, xlabel='Date', ylabel='count'>

# %%
Mon= pd.to_datetime(df3.Date).dt.month

# %%
plt.figure(figsize=(10,8))
plt.title('Humidity of month')
sns.countplot(x=Mon)
# Out:
# <AxesSubplot:title={'center':'Humidity of month'}, xlabel='Date', ylabel='count'>

# %%
dd= pd.to_datetime(df3.Date).dt.day

# %%
plt.figure(figsize=(10,8))
plt.title('Humidity of day')
sns.countplot(x=dd)
# Out:
# <AxesSubplot:title={'center':'Humidity of day'}, xlabel='Date', ylabel='count'>

# %%
plt.figure(figsize=(8,6), dpi=90)
plt.scatter(df3['Time'],df3['Humidity'])
plt.xlabel("Time")
plt.xticks(rotation=90)
plt.ylabel("Humidity")
plt.grid()
plt.show()

# %%
df3
# Out:
#              Date          Time        Summary Precip Type  Temperature (C)  \
# 0      2006-04-01  00:00:00.000  Partly Cloudy        rain         9.472222
# 1      2006-04-01  01:00:00.000  Partly Cloudy        rain         9.355556
# 2      2006-04-01  02:00:00.000  Mostly Cloudy        rain         9.377778
# 3      2006-04-01  03:00:00.000  Partly Cloudy        rain         8.288889
# 4      2006-04-01  04:00:00.000  Mostly Cloudy        rain         8.755556
# ...           ...           ...            ...         ...              ...
# 96448  2016-09-09  19:00:00.000  Partly Cloudy        rain        26.016667
# 96449  2016-09-09  20:00:00.000  Partly Cloudy        rain        24.583333
# 96450  2016-09-09  21:00:00.000  Partly Cloudy        rain        22.038889
# 96451  2016-09-09  22:00:00.000  Partly Cloudy        rain        21.522222
# 96452  2016-09-09  23:00:00.000  Partly Cloudy        rain        20.438889
#
#        Wind Speed (km/h)  Pressure (millibars)  Humidity
# ...

# %%
plt.figure(figsize=(8,6))
plt.scatter(df3['Temperature (C)'], df3['Humidity'])
plt.xlabel('TEMPERATURE(C)')
plt.ylabel('Humidity')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(df3['Wind Speed (km/h)'], df3['Humidity'])
plt.xlabel('Wind Speed (km/h)')
plt.ylabel('Humidity')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(df3['Pressure (millibars)'], df3['Humidity'])
plt.xlabel('Pressure (millibars)')
plt.ylabel('Humidity')
plt.grid()
plt.show()
