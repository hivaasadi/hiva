# %% [markdown]
# **IN THE NAME OF GOD**
#
# **IMT Machine Learning Practice Number 5**
#
# Please Put your name here : hiva asadi

# %% [markdown]
# In this notebook, we are going to challenge ourselves.
#
# Read the following text carefully
#
# Then fill the cells with (TODO) type
#
# First we created a dataframe with random values

# %% [markdown]
# Exercise 1 : (easy one)

# %%
import pandas as pd
data = pd.DataFrame({'group':['a', 'a', 'a', 'b','b', 'b', 'c', 'c','c'],'ounces':[4, 3, 12, 6, 7.5, 8, 3, 5, 6]})
data
# Out:
#   group  ounces
# 0     a     4.0
# 1     a     3.0
# 2     a    12.0
# 3     b     6.0
# 4     b     7.5
# 5     b     8.0
# 6     c     3.0
# 7     c     5.0
# 8     c     6.0

# %% [markdown]
# Step 1:  Let's sort the dataframe by 'ounces', make ascending = True and inplace = Fales

# %%
data.sort_values('ounces', axis=0 ,ascending= True,inplace = False )
# Out:
#   group  ounces
# 1     a     3.0
# 6     c     3.0
# 0     a     4.0
# 7     c     5.0
# 3     b     6.0
# 8     c     6.0
# 4     b     7.5
# 5     b     8.0
# 2     a    12.0

# %% [markdown]
# Step 2: Let's sort the dataframe by 'group', make ascending = True and inplace = Fales

# %%
data.sort_values('group', axis=0 ,ascending= True,inplace = False )
# Out:
#   group  ounces
# 0     a     4.0
# 1     a     3.0
# 2     a    12.0
# 3     b     6.0
# 4     b     7.5
# 5     b     8.0
# 6     c     3.0
# 7     c     5.0
# 8     c     6.0

# %% [markdown]
# Step 3: Now remove Duplicated values from 'group'

# %%
finall=data.drop_duplicates('group')

# %% [markdown]
# Step 4: Now plot your finall edited dataframe

# %%
finall
# Out:
#   group  ounces
# 0     a     4.0
# 3     b     6.0
# 6     c     3.0

# %% [markdown]
# Exercise 2: (normal)

# %% [markdown]
# In this part, we will cover the basic plot types and parameters of Matplotlib. Then we going to make it complex.

# %% [markdown]
# First, importing our libraries.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# Dataset for this part

# %%
np.random.seed(0)

df = pd.DataFrame(data={'a':np.random.randint(0, 100, 30),
                        'b':np.random.randint(0, 100, 30),
                        'c':np.random.randint(0, 100, 30)})
df.head()
# Out:
#     a   b   c
# 0  44  47  17
# 1  47  64  79
# 2  64  82   4
# 3  67  99  42
# 4  67  88  58

# %% [markdown]
# Let's begin our first plot

# %% [markdown]
# Now, complete above plots with below comments

# %%
fig, axs= plt.subplots(2,2, figsize=(15,8)) # This creates a figure of size 15*8


axs[0, 0].plot(df['a'])
axs[0, 0].set_title("axis(00)")
axs[0, 1].plot(df['b'])
axs[0, 1].set_title("axis(01)")
axs[1, 0].plot(df['c'])
axs[1, 0].set_title("axis(10)")
axs[1, 1].plot(range(len(df)))
axs[1, 1].set_title("axis(11)")


plt.show()

# %% [markdown]
# **********
# ****IMT is the best! Nah?!****
# **********

# %% [markdown]
# In this cell, it's worth mentioning a convenient function that makes our plots much prettier without having a configure theme

# %% [markdown]
# This function is 'seaborn.set_style('dakgrid')' from the library seaborn

# %%
sns.set_style('darkgrid') # setting the plotting style
                          # we only need to call this once,
                          # usually before we start plotting.
        
fig, axs= plt.subplots(1,1, figsize=(15,8))
axs.plot(df['a'])
axs.plot(df['b'])
plt.show()

# %% [markdown]
# At the end of this part, Lets combining subplots with Line Graph and using Legend

# %%
fig,axs=plt.subplots(3,1, figsize=(15,8))

fig.suptitle('chart')

axs[0].plot(df['a'])
axs[0].set_title("row(1)")
axs[1].plot(df['b'])
axs[1].set_title("row(2)")
axs[2].plot(df['c'])
axs[2].set_title("row(3)")




plt.show()

# %% [markdown]
# Exercise 3: (hard)
#
# :)

# %% [markdown]
# How to change the order of columns of a DataFrame???

# %% [markdown]
# There are 3 questions.
#     1. in df, interchange columns 'a' and 'c'
#
#     2. Create a generic function to interchange two columns, without hardcoding column names.
#
#     3. Sort the columns in reverse alphabetical order, that is colume 'e' first through column 'a' last.

# %%
# input
df = pd.DataFrame(np.arange(20).reshape(-1, 5), columns=list('abcde'))

# %%
df[list('cbade')]
# Out:
#     c   b   a   d   e
# 0   2   1   0   3   4
# 1   7   6   5   8   9
# 2  12  11  10  13  14
# 3  17  16  15  18  19

# %%
def change_cols(df, col1, col2):
    colnames = df.columns.tolist()
    i1, i2 = colnames.index(col1), colnames.index(col2)
    colnames[i2], colnames[i1] = colnames[i1], colnames[i2]
    return df[colnames]

df =change_cols(df, 'b', 'e')
df
# Out:
#     a   e   c   d   b
# 0   0   4   2   3   1
# 1   5   9   7   8   6
# 2  10  14  12  13  11
# 3  15  19  17  18  16

# %%
df.sort_index(axis=1, ascending=False, inplace=True)
df
# Out:
#     e   d   c   b   a
# 0   4   3   2   1   0
# 1   9   8   7   6   5
# 2  14  13  12  11  10
# 3  19  18  17  16  15
